# %% [markdown]
# # 3 Classification

# %% [markdown]
# ## 3.1 Churn prediction project

# %% [markdown]
# Dataset: [Telco Customer Churn](https://www.kaggle.com/datasets/blastchar/telco-customer-churn?resource=download()

# %% [markdown]
# ## 3.2 Data preparation

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv') # read csv files

# %%
len(df)
# Out:
# 7043

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_') # replace the space separator in the columns names of a dataframe

# %%
categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)
categorical_columns
# Out:
# ['customerid',
#  'gender',
#  'partner',
#  'dependents',
#  'phoneservice',
#  'multiplelines',
#  'internetservice',
#  'onlinesecurity',
#  'onlinebackup',
#  'deviceprotection',
#  'techsupport',
#  'streamingtv',
#  'streamingmovies',
#  'contract',
#  'paperlessbilling',
#  'paymentmethod',
#  'totalcharges',
#  'churn']

# %%
for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')

# %%
tc = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
df.totalcharges = df.totalcharges.fillna(0)

# %%
df.churn.head()
# Out:
# 0     no
# 1     no
# 2    yes
# 3     no
# 4    yes
# Name: churn, dtype: object

# %%
df.churn =  (df.churn == 'yes').astype(int)# replace NAs with some value

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerid              7590-vhveg    5575-gnvde      3668-qpybk
# gender                      female          male            male
# seniorcitizen                    0             0               0
# partner                        yes            no              no
# dependents                      no            no              no
# tenure                           1            34               2
# phoneservice                    no           yes             yes
# multiplelines     no_phone_service            no              no
# internetservice                dsl           dsl             dsl
# onlinesecurity                  no           yes             yes
# onlinebackup                   yes            no             yes
# deviceprotection                no           yes              no
# techsupport                     no            no              no
# ...

# %% [markdown]
# ## 3.3 Setting up the validation framework
#
# - Perform the train/validation/test split with Scikit-Learn

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)

# %%
len(df_full_train), len(df_test)
# Out:
# (5634, 1409)

# %%
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

# %%
len(df_train), len(df_test), len(df_val)
# Out:
# (4225, 1409, 1409)

# %%
df_train
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 5323  1448-cywkc  female              0     yes        yes      58
# 3026  6127-isgtu  female              0     yes         no      16
# 1860  3279-dyzqm    male              0     yes        yes      71
# 5251  8485-gjcdn  female              1      no         no       5
# 2642  2195-zrvax  female              0     yes         no      47
# ...          ...     ...            ...     ...        ...     ...
# 3977  4778-izarl    male              0     yes         no      63
# 6273  4342-hentk  female              1      no         no       2
# 3790  6598-rffvi    male              0      no         no       2
# 5712  8204-tifgj  female              0      no         no      23
# 3405  0744-gknge  female              0     yes        yes      64
#
#      phoneservice multiplelines internetservice       onlinesecurity  ...  \
# 5323          yes           yes     fiber_optic                   no  ...
# ...

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_train.reset_index(drop=True)
df_test = df_train.reset_index(drop=True)

# %%
y_train = df_train.churn.values
y_val = df_val .churn.values
y_test = df_test.churn.values

# %%
del df_train['churn']
del df_val['churn']
del df_test['churn']

# %% [markdown]
# ## 3.4 Exploratory data analysis
# - Check missing values
# - Look at the target variable (churn)
# - Look at numerical and categorical variables

# %%
df_full_train = df_full_train.reset_index(drop=True) # shuffle

# %%
df_full_train.isnull().sum() # check for missing values
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
df_full_train.churn.value_counts(normalize=True)
# Out:
# churn
# 0    0.730032
# 1    0.269968
# Name: proportion, dtype: float64

# %%
global_churn_rate  = df_full_train.churn.mean()
round(global_churn_rate, 2)
# Out:
# np.float64(0.27)

# %%
df_full_train.dtypes # Check for numerical variable
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges        float64
# churn                 int64
# dtype: object

# %%
numerical  = ['tenure', 'monthlycharges','totalcharges']
numerical
# Out:
# ['tenure', 'monthlycharges', 'totalcharges']

# %%
df_full_train.columns # All columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
categorical = ['gender', 'seniorcitizen', 'partner', 'dependents',
        'phoneservice', 'multiplelines', 'internetservice',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
       'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
       'paymentmethod']

categorical
# Out:
# ['gender',
#  'seniorcitizen',
#  'partner',
#  'dependents',
#  'phoneservice',
#  'multiplelines',
#  'internetservice',
#  'onlinesecurity',
#  'onlinebackup',
#  'deviceprotection',
#  'techsupport',
#  'streamingtv',
#  'streamingmovies',
#  'contract',
#  'paperlessbilling',
#  'paymentmethod']

# %%
df_full_train[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %% [markdown]
# ## 3.5 Feature importance: Churn rate and risk ratio
# - Churn rate
# - Risk ratio
# - Mutual information - later

# %% [markdown]
# **Churn rate**

# %%
df_full_train.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  5442-pptjy    male              0     yes        yes      12          yes
# 1  6261-rcvns  female              0      no         no      42          yes
# 2  2176-osjuv    male              0     yes         no      71          yes
# 3  6161-erdgd    male              0     yes        yes      71          yes
# 4  2364-ufrom    male              0      no         no      30          yes
#
#   multiplelines internetservice       onlinesecurity  ...  \
# 0            no              no  no_internet_service  ...
# 1            no             dsl                  yes  ...
# 2           yes             dsl                  yes  ...
# 3           yes             dsl                  yes  ...
# 4            no             dsl                  yes  ...
#
#       deviceprotection          techsupport          streamingtv  \
# 0  no_internet_service  no_internet_service  no_internet_service
# ...

# %%
churn_female = df_full_train[df_full_train.gender == 'female'].churn.mean()
np.round(churn_female, decimals=2).item()
# Out:
# 0.28

# %%
churn_male = df_full_train[df_full_train.gender == 'male'].churn.mean()
np.round(churn_male, decimals=2).item()
# Out:
# 0.26

# %%
global_churn = df_full_train.churn.mean()
np.round(global_churn, decimals=2).item()
# Out:
# 0.27

# %%
df_full_train.partner.value_counts()
# Out:
# partner
# no     2932
# yes    2702
# Name: count, dtype: int64

# %%
churn_with_partner = df_full_train[df_full_train.partner == 'yes'].churn.mean()
np.round(churn_with_partner, decimals=2).item()
# Out:
# 0.21

# %%
churn_no_partner = df_full_train[df_full_train.partner == 'no'].churn.mean()
np.round(churn_no_partner, decimals=2).item()
# Out:
# 0.33

# %%
churn_rate_with_partner = global_churn - churn_with_partner
np.round(churn_rate_with_partner, decimals=2).item()
# Out:
# 0.06

# %%
churn_rate_no_partner = global_churn - churn_no_partner
np.round(churn_rate_no_partner, decimals=2).item()
# Out:
# -0.06

# %%
churn_rate_female = global_churn - churn_female
np.round(churn_rate_female, decimals=2).item()
# Out:
# -0.01

# %%
churn_rate_male = global_churn - churn_male
np.round(churn_rate_male, decimals=2).item()
# Out:
# 0.01

# %% [markdown]
# **Risk ratio**

# %%
churn_no_partner / global_churn
# Out:
# np.float64(1.2216593879412643)

# %%
churn_with_partner / global_churn
# Out:
# np.float64(0.7594724924338315)

# %%
from IPython.display import display

# %%
for c in categorical:
    print(c)
    df_group = df_full_train.groupby(c).churn.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_churn
    df_group['risk'] = df_group['mean'] / global_churn
    display(df_group)
    print()
    print()
# Out:
# gender
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006755  0.974980
# seniorcitizen
#                    mean  count      diff      risk
# seniorcitizen
# 0              0.242270   4722 -0.027698  0.897403
# 1              0.413377    912  0.143409  1.531208
# partner
#              mean  count      diff      risk
# partner
# no       0.329809   2932  0.059841  1.221659
# yes      0.205033   2702 -0.064935  0.759472
# dependents
#                 mean  count      diff      risk
# dependents
# no          0.313760   3968  0.043792  1.162212
# yes         0.165666   1666 -0.104302  0.613651
# phoneservice
#                   mean  count      diff      risk
# phoneservice
# no            0.241316    547 -0.028652  0.893870
# yes           0.273049   5087  0.003081  1.011412
# multiplelines
#                       mean  count      diff      risk
# multiplelines
# ...

# %% [markdown]
# ## 3.6 Feature importance: Correlation
# Mutual information -a  concept from information theory, it tells us how much we can learn about one
# variable if we know the value of another
# - [Mutual information](https://en.wikipedia.org/wiki/Mutual_information)

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df_full_train.churn, df_full_train.contract, contingency=None)
# Out:
# 0.0983203874041556

# %%
mutual_info_score(df_full_train.churn, df_full_train.gender, contingency=None)
# Out:
# 0.0001174846211139946

# %%
mutual_info_score(df_full_train.churn, df_full_train.partner, contingency=None)
# Out:
# 0.009967689095399745

# %%
def mutual_info_churn_score(series):
    return mutual_info_score(series, df_full_train.churn)

# %%
mutual_info = df_full_train[categorical].apply(mutual_info_churn_score)
mutual_info.sort_values(ascending=False)
# Out:
# contract            0.098320
# onlinesecurity      0.063085
# techsupport         0.061032
# internetservice     0.055868
# onlinebackup        0.046923
# deviceprotection    0.043453
# paymentmethod       0.043210
# streamingtv         0.031853
# streamingmovies     0.031581
# paperlessbilling    0.017589
# dependents          0.012346
# partner             0.009968
# seniorcitizen       0.009410
# multiplelines       0.000857
# phoneservice        0.000229
# gender              0.000117
# dtype: float64

# %% [markdown]
# ## 3.7 Feature importance: Correlation
# How about numerical columns?
# - [Correlation coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient)

# %%
df_full_train.tenure.max().item()
# Out:
# 72

# %%
df_full_train[numerical].corrwith(df_full_train.churn)
# Out:
# tenure           -0.351885
# monthlycharges    0.196805
# totalcharges     -0.196353
# dtype: float64

# %%
df_full_train[numerical].corrwith(df_full_train.churn).abs()
# Out:
# tenure            0.351885
# monthlycharges    0.196805
# totalcharges      0.196353
# dtype: float64

# %%
df_full_train[df_full_train.tenure <= 2].churn.mean().item()
# Out:
# 0.5953420669577875

# %%
df_full_train[(df_full_train.tenure > 2) & (df_full_train.tenure <= 12)].churn.mean().item()
# Out:
# 0.3994413407821229

# %%
df_full_train[df_full_train.tenure > 12].churn.mean().item()
# Out:
# 0.17634908339788277

# %%
df_full_train[df_full_train.monthlycharges <= 20].churn.mean()
# Out:
# np.float64(0.08795411089866156)

# %%
df_full_train[(df_full_train.monthlycharges > 20) & (df_full_train.monthlycharges <= 50)].churn.mean().item()
# Out:
# 0.18340943683409436

# %%
df_full_train[df_full_train.monthlycharges > 50 ].churn.mean().item()
# Out:
# 0.32499341585462205

# %% [markdown]
# ## 3.8 One-hot encoding
# - Use Scikit-Learn to endo categorial feature

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
df_train[categorical + numerical]
# Out:
#       gender  seniorcitizen partner dependents phoneservice multiplelines  \
# 0     female              0     yes        yes          yes           yes
# 1     female              0     yes         no          yes           yes
# 2       male              0     yes        yes          yes            no
# 3     female              1      no         no          yes            no
# 4     female              0     yes         no          yes            no
# ...      ...            ...     ...        ...          ...           ...
# 4220    male              0     yes         no          yes            no
# 4221  female              1      no         no          yes            no
# 4222    male              0      no         no          yes            no
# 4223  female              0      no         no          yes            no
# 4224  female              0     yes        yes          yes           yes
#
#      internetservice       onlinesecurity         onlinebackup  \
# ...

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False).fit(train_dicts)

# %%
dv.get_feature_names_out()
# Out:
# array(['contract=month-to-month', 'contract=one_year',
#        'contract=two_year', 'dependents=no', 'dependents=yes',
#        'deviceprotection=no', 'deviceprotection=no_internet_service',
#        'deviceprotection=yes', 'gender=female', 'gender=male',
#        'internetservice=dsl', 'internetservice=fiber_optic',
#        'internetservice=no', 'monthlycharges', 'multiplelines=no',
#        'multiplelines=no_phone_service', 'multiplelines=yes',
#        'onlinebackup=no', 'onlinebackup=no_internet_service',
#        'onlinebackup=yes', 'onlinesecurity=no',
#        'onlinesecurity=no_internet_service', 'onlinesecurity=yes',
#        'paperlessbilling=no', 'paperlessbilling=yes', 'partner=no',
#        'partner=yes', 'paymentmethod=bank_transfer_(automatic)',
#        'paymentmethod=credit_card_(automatic)',
#        'paymentmethod=electronic_check', 'paymentmethod=mailed_check',
#        'phoneservice=no', 'phoneservice=yes', 'seniorcitizen',
# ...

# %%
X_train = dv.transform(train_dicts)

# %%
val_dicts = df_train[categorical + numerical].to_dict(orient='records')

# %%
X_val = dv.transform(val_dicts)
